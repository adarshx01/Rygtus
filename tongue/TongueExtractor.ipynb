# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.2/922.2 kB 14.1 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="AzHXlB7zJGHQabwRv35A")
project = rf.workspace("avinash-king-pdhh5").project("tongue-hkdkr-uxugm")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 25.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to tongue-1 in yolov11:: 100%|██████████| 7864/7864 [00:00<00:00, 8405.73it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)
# Train the model
results = model.train(data="/content/tongue-1/data.yaml", epochs=10, imgsz=640)
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 67.2MB/s]
# Ultralytics 8.3.85 🚀 Python-3.11.11 torch-2.5.1+cpu CPU (Intel Xeon 2.00GHz)
# ...

# %%
test1=model.predict("/content/tongue-1/test/images/1717188644881_jpg.rf.b812fa77424d5bbd38af8085c3b3021e.jpg")
test1[0].show()
# Out:
# image 1/1 /content/tongue-1/test/images/1717188644881_jpg.rf.b812fa77424d5bbd38af8085c3b3021e.jpg: 640x640 1 tongue, 63.8ms
# Speed: 2.2ms preprocess, 63.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
test2=model.predict("/content/tongue-1/test/images/1717764635525_jpg.rf.ab1b694c7f5961f3a0f6c6252673852f.jpg")
test2[0].show()
# Out:
# image 1/1 /content/tongue-1/test/images/1717764635525_jpg.rf.ab1b694c7f5961f3a0f6c6252673852f.jpg: 640x640 1 tongue, 55.6ms
# Speed: 2.2ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
# !zip -r /content/tongue-model.zip /content/runs/
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 14%)
#   adding: content/runs/detect/train/labels_correlogram.jpg (deflated 35%)
#   adding: content/runs/detect/train/PR_curve.png (deflated 29%)
#   adding: content/runs/detect/train/val_batch1_labels.jpg (deflated 10%)
#   adding: content/runs/detect/train/args.yaml (deflated 53%)
#   adding: content/runs/detect/train/R_curve.png (deflated 19%)
#   adding: content/runs/detect/train/results.csv (deflated 58%)
#   adding: content/runs/detect/train/val_batch2_labels.jpg (deflated 12%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 10%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 10%)
#   adding: content/runs/detect/train/labels.jpg (deflated 30%)
# ...
